# %%
import csv
import pandas as pd
import urllib
import urllib2
import datetime
import numpy as np;

# %%
df = pd.read_csv('../Data/companylist.csv')
stock_tickers = df.Symbol

# %%
##  Calculate moving average for all points over n data points in a list,
##  then also removes n - 1 data points and returns that as a separate list

def calculateMovingAverageList(data, n):    
    currentAverage = 0;
    internalValues = [];
    movingAverage = [];

    for i in range(n):
        # Append all values to internalValues;
        # print i;
        internalValues.append(data[i]);
        
    currentAverage = np.mean(internalValues);
    movingAverage.append(currentAverage);
        
    for i in range(n + 1, len(data)):
        # print i;
        del internalValues[0]; # Delete first index
        internalValues.append(data[i]); # Add data at i;
        currentAverage = np.mean(internalValues);
        movingAverage.append(currentAverage);
        
    return movingAverage, data[n:];

# %%
##  Append 0 data

def fixTimeData(timeList, n, data, movingAverage):
    for i in range(n):
        timeList.append(i);
        movingAverage.insert(0, 0);
        
    for j in range(i, len(data) - 1):
        timeList.append(j)
        
    return movingAverage;

# %%
def calculateSlope(movingAverageList):
    dX = 1.0;
    dY = [];
    
    for i in range(len(movingAverageList) - 1):
        dY.append(movingAverageList[i + 1] - movingAverageList[i]);
        
    dY.append(movingAverageList[i + 1]);
    slope = [dy / dX for dy in dY];
    return slope;

# %%
final_results = {};

# %%
import pickle
results_from_script = pickle.load( open( "../Python/final_results_market.p", "rb" ) )

# %%
for stock in range(0, len(stock_tickers)):
    print "Currently calculating for stock: " + stock_tickers[stock] + " (progress: " + str(stock) + " of " + str(len(stock_tickers)) + ")"
    dataDict = {};
    times = [];
    closing = [];
    continueBoolean = False;

    with open('../Data_From_Script/getprices_' + stock_tickers[stock] + '_long.txt', 'rb') as csvfile:
        pricereader = csv.reader(csvfile, delimiter=' ', quotechar='|')
        for i, row in enumerate(pricereader):
            if i > 6:
                try:
                    dataDict[i] = row;
                    values = row[0].split(',');
                    times.append(values[0]);
                    closing.append(float(values[1]));
                except IndexError:
                    continueBoolean = True;
                    continue;
                    
    if continueBoolean == True:
        continue;
                
    timesUTC = [];

    currUnixTime = 0;
    currTime = None;

    for i in range(len(times)):
        if times[i][0] == 'a':
            #print i;
            currUnixTime = int(times[i][1:]);
            #print currUnixTime;
            currTime = datetime.datetime.utcfromtimestamp(currUnixTime)
            #print currTime
            timesUTC.append(currTime);
        else:
            #print currUnixTime
            timesUTC.append(datetime.datetime.utcfromtimestamp(currUnixTime + int(times[i])));
            
    if len(closing) == 0:
        continue;

    try:
        movingAverage78, shorterData78 = calculateMovingAverageList(closing, 78);
        timeStamp78 = timesUTC[78:];
    except IndexError:
        continue;
    
    movingAverage39, shorterData39 = calculateMovingAverageList(closing, 39);
    timeStamp39 = timesUTC[39:];
    
    movingAverage20, shorterData20 = calculateMovingAverageList(closing, 20);
    timeStamp20 = timesUTC[20:];
    
    movingAverage5, shorterData5 = calculateMovingAverageList(closing, 5);
    timeStamp5 = timesUTC[5:];
    
    fixTime5 = [];
    fixTime20 = [];
    fixTime39 = [];
    fixTime78 = [];

    movingAverage5 = fixTimeData(fixTime5, 5, closing, movingAverage5);
    movingAverage20 = fixTimeData(fixTime20, 20, closing, movingAverage20);
    movingAverage39 = fixTimeData(fixTime39, 39, closing, movingAverage39);
    movingAverage78 = fixTimeData(fixTime78, 78, closing, movingAverage78);
    
    slope78 = calculateSlope(movingAverage78);
    slope39 = calculateSlope(movingAverage39);
    slope20 = calculateSlope(movingAverage20);
    slope5 = calculateSlope(movingAverage5);
    
    buyPoints = [];
    errorBoolean = False;
    
    for i in range(len(slope78)):
        try:
            if (slope78[i] >= 0) and (slope39[i] > 0) and (slope20[i] > 0) and (slope5[i] > 0) and (closing[i] > movingAverage78[i]):
                buyPoints.append(i);
        except IndexError:
            errorBoolean = True;
            continue;
            
    if errorBoolean == True:
        continue;
            
    sellPoints = [];

    for i in range(len(slope78)):
        if (slope78[i] < 0) and (slope39[i] < 0) and (slope20[i] < 0) and (slope5[i] < 0) and (closing[i] < movingAverage78[i]):
            sellPoints.append(i);
            
    ##  Find one buyPoint and one sellPoint

    buy_sell_Points_tuple_list = []

    for buyPoint in buyPoints:
        buy_sell_Points_tuple_list.append((buyPoint, "buy"));

    for sellPoint in sellPoints:
        buy_sell_Points_tuple_list.append((sellPoint, "sell"));
        
    buy_sell_Points_tuple_list.sort(key=lambda tup: tup[0])  # sorts in place
    
    buy_list = [];
    sell_list = [];

    isBuy = True;

    for value in buy_sell_Points_tuple_list:
        if isBuy == True and value[1] == 'buy':
            buy_list.append(value[0]);
            isBuy = False;
        elif isBuy == False and value[1] == 'sell':
            sell_list.append(value[0]);
            isBuy = True;
            
    ##  Calculate earnings (from just sell minus buy)
    earnings = [];
    number_of_transactions = 0;

    for i in range(len(sell_list)):
        earnings.append(closing[sell_list[i]] - closing[buy_list[i]]);
        number_of_transactions += 1;

    for i in range(1, len(buy_list)):
        # print buy_list[i], sell_list[i - 1];
        # print closing[buy_list[i]], closing
        earnings.append(-(closing[buy_list[i]] - closing[sell_list[i - 1]]));
        number_of_transactions += 1;
        
    price_of_transactions = - 7 * number_of_transactions * 2;

    ## Net sum with number_of_shares amount of stock
    
    if len(buy_list) == 0:
        number_of_shares = 0;
    else:
        number_of_shares = 10000 / closing[buy_list[0]];

    ## Percentage gain
    if len(buy_list) == 0:
        starting_amount = 0;
    else:
        starting_amount = closing[buy_list[0]] * number_of_shares + 7;
    
    final_amount = starting_amount + np.sum(earnings) * number_of_shares - price_of_transactions;
    
    final_results[stock_tickers[stock]] = (buy_list, sell_list, number_of_shares, earnings, starting_amount, final_amount);
# Out:
# Currently calculating for stock: PIH (progress: 0 of 341)
# Currently calculating for stock: TURN (progress: 1 of 341)
# Currently calculating for stock: FLWS (progress: 2 of 341)
# Currently calculating for stock: FCCY (progress: 3 of 341)
# Currently calculating for stock: SRCE (progress: 4 of 341)
# Currently calculating for stock: VNET (progress: 5 of 341)
# Currently calculating for stock: TWOU (progress: 6 of 341)
# Currently calculating for stock: JOBS (progress: 7 of 341)
# Currently calculating for stock: CAFD (progress: 8 of 341)
# Currently calculating for stock: EGHT (progress: 9 of 341)
# Currently calculating for stock: AVHI (progress: 10 of 341)
# Currently calculating for stock: SHLM (progress: 11 of 341)
# Currently calculating for stock: AAON (progress: 12 of 341)
# Currently calculating for stock: ABAX (progress: 13 of 341)
# Currently calculating for stock: ABEO (progress: 14 of 341)
# Currently calculating for stock: ABEOW (progress: 15 of 341)
# Currently calculating for stock: ABIL (progress: 16 of 341)
# Currently calculating for stock: ABMD (progress: 17 of 341)
# Currently calculating for stock: AXAS (progress: 18 of 341)
# Currently calculating for stock: ACIU (progress: 19 of 341)
# Currently calculating for stock: ACIA (progress: 20 of 341)
# Currently calculating for stock: ACTG (progress: 21 of 341)
# Currently calculating for stock: ACHC (progress: 22 of 341)
# Currently calculating for stock: ACAD (progress: 23 of 341)
# Currently calculating for stock: ACST (progress: 24 of 341)
# Currently calculating for stock: AXDX (progress: 25 of 341)
# Currently calculating for stock: XLRN (progress: 26 of 341)
# Currently calculating for stock: ANCX (progress: 27 of 341)
# Currently calculating for stock: ARAY (progress: 28 of 341)
# Currently calculating for stock: ACRX (progress: 29 of 341)
# Currently calculating for stock: ACET (progress: 30 of 341)
# Currently calculating for stock: AKAO (progress: 31 of 341)
# Currently calculating for stock: ACHN (progress: 32 of 341)
# Currently calculating for stock: ACIW (progress: 33 of 341)
# Currently calculating for stock: ACRS (progress: 34 of 341)
# Currently calculating for stock: ACNB (progress: 35 of 341)
# Currently calculating for stock: ACOR (progress: 36 of 341)
# Currently calculating for stock: SQZZ (progress: 37 of 341)
# Currently calculating for stock: ATVI (progress: 38 of 341)
# Currently calculating for stock: ACTA (progress: 39 of 341)
# Currently calculating for stock: ACXM (progress: 40 of 341)
# Currently calculating for stock: ADMS (progress: 41 of 341)
# Currently calculating for stock: ADMP (progress: 42 of 341)
# Currently calculating for stock: ADAP (progress: 43 of 341)
# Currently calculating for stock: ADUS (progress: 44 of 341)
# Currently calculating for stock: AEY (progress: 45 of 341)
# Currently calculating for stock: IOTS (progress: 46 of 341)
# Currently calculating for stock: ADMA (progress: 47 of 341)
# Currently calculating for stock: ADBE (progress: 48 of 341)
# Currently calculating for stock: ADOM (progress: 49 of 341)
# Currently calculating for stock: ADTN (progress: 50 of 341)
# Currently calculating for stock: ADRO (progress: 51 of 341)
# Currently calculating for stock: AAAP (progress: 52 of 341)
# Currently calculating for stock: ADES (progress: 53 of 341)
# Currently calculating for stock: AEIS (progress: 54 of 341)
# Currently calculating for stock: AMD (progress: 55 of 341)
# Currently calculating for stock: ADXS (progress: 56 of 341)
# Currently calculating for stock: ADXSW (progress: 57 of 341)
# Currently calculating for stock: ADVM (progress: 58 of 341)
# Currently calculating for stock: AEGN (progress: 59 of 341)
# Currently calculating for stock: AGLE (progress: 60 of 341)
# Currently calculating for stock: AEHR (progress: 61 of 341)
# Currently calculating for stock: AMTX (progress: 62 of 341)
# Currently calculating for stock: AERI (progress: 63 of 341)
# Currently calculating for stock: AVAV (progress: 64 of 341)
# Currently calculating for stock: AEZS (progress: 65 of 341)
# Currently calculating for stock: AEMD (progress: 66 of 341)
# Currently calculating for stock: GNMX (progress: 67 of 341)
# Currently calculating for stock: AFMD (progress: 68 of 341)
# Currently calculating for stock: AGEN (progress: 69 of 341)
# Currently calculating for stock: AGRX (progress: 70 of 341)
# Currently calculating for stock: AGYS (progress: 71 of 341)
# Currently calculating for stock: AGIO (progress: 72 of 341)
# Currently calculating for stock: AGNC (progress: 73 of 341)
# Currently calculating for stock: AGNCB (progress: 74 of 341)
# Currently calculating for stock: AGNCP (progress: 75 of 341)
# Currently calculating for stock: AGFS (progress: 76 of 341)
# Currently calculating for stock: AGFSW (progress: 77 of 341)
# Currently calculating for stock: ALRN (progress: 78 of 341)
# Currently calculating for stock: AIMT (progress: 79 of 341)
# Currently calculating for stock: AIRT (progress: 80 of 341)
# Currently calculating for stock: ATSG (progress: 81 of 341)
# Currently calculating for stock: AIRG (progress: 82 of 341)
# Currently calculating for stock: AMCN (progress: 83 of 341)
# Currently calculating for stock: AKAM (progress: 84 of 341)
# Currently calculating for stock: AKTX (progress: 85 of 341)
# Currently calculating for stock: AKCA (progress: 86 of 341)
# Currently calculating for stock: AKBA (progress: 87 of 341)
# Currently calculating for stock: AKER (progress: 88 of 341)
# Currently calculating for stock: AKRX (progress: 89 of 341)
# Currently calculating for stock: AKTS (progress: 90 of 341)
# Currently calculating for stock: ALRM (progress: 91 of 341)
# Currently calculating for stock: ALSK (progress: 92 of 341)
# Currently calculating for stock: AMRI (progress: 93 of 341)
# Currently calculating for stock: ALBO (progress: 94 of 341)
# Currently calculating for stock: ABDC (progress: 95 of 341)
# Currently calculating for stock: ADHD (progress: 96 of 341)
# Currently calculating for stock: ALDR (progress: 97 of 341)
# Currently calculating for stock: ALDX (progress: 98 of 341)
# Currently calculating for stock: ALXN (progress: 99 of 341)
# Currently calculating for stock: ALCO (progress: 100 of 341)
# Currently calculating for stock: ALGN (progress: 101 of 341)
# Currently calculating for stock: ALIM (progress: 102 of 341)
# Currently calculating for stock: ALJJ (progress: 103 of 341)
# Currently calculating for stock: ALKS (progress: 104 of 341)
# Currently calculating for stock: ABTX (progress: 105 of 341)
# Currently calculating for stock: ALGT (progress: 106 of 341)
# Currently calculating for stock: AIQ (progress: 107 of 341)
# Currently calculating for stock: AHGP (progress: 108 of 341)
# Currently calculating for stock: AMMA (progress: 109 of 341)
# Currently calculating for stock: ARLP (progress: 110 of 341)
# Currently calculating for stock: AHPI (progress: 111 of 341)
# Currently calculating for stock: AMOT (progress: 112 of 341)
# Currently calculating for stock: ALQA (progress: 113 of 341)
# Currently calculating for stock: ALLT (progress: 114 of 341)
# Currently calculating for stock: MDRX (progress: 115 of 341)
# Currently calculating for stock: AFAM (progress: 116 of 341)
# Currently calculating for stock: ALNY (progress: 117 of 341)
# Currently calculating for stock: AOSL (progress: 118 of 341)
# Currently calculating for stock: GOOG (progress: 119 of 341)
# Currently calculating for stock: GOOGL (progress: 120 of 341)
# Currently calculating for stock: SMCP (progress: 121 of 341)
# Currently calculating for stock: ATEC (progress: 122 of 341)
# Currently calculating for stock: SWIN (progress: 123 of 341)
# Currently calculating for stock: AABA (progress: 124 of 341)
# Currently calculating for stock: ALT (progress: 125 of 341)
# Currently calculating for stock: ASPS (progress: 126 of 341)
# Currently calculating for stock: AIMC (progress: 127 of 341)
# Currently calculating for stock: AMAG (progress: 128 of 341)
# Currently calculating for stock: AMRN (progress: 129 of 341)
# Currently calculating for stock: AMRK (progress: 130 of 341)
# Currently calculating for stock: AYA (progress: 131 of 341)
# Currently calculating for stock: AMZN (progress: 132 of 341)
# Currently calculating for stock: AMBC (progress: 133 of 341)
# Currently calculating for stock: AMBCW (progress: 134 of 341)
# Currently calculating for stock: AMBA (progress: 135 of 341)
# Currently calculating for stock: AMCX (progress: 136 of 341)
# Currently calculating for stock: DOX (progress: 137 of 341)
# Currently calculating for stock: AMDA (progress: 138 of 341)
# Currently calculating for stock: AMED (progress: 139 of 341)
# Currently calculating for stock: UHAL (progress: 140 of 341)
# Currently calculating for stock: ATAX (progress: 141 of 341)
# Currently calculating for stock: AMOV (progress: 142 of 341)
# Currently calculating for stock: AAL (progress: 143 of 341)
# Currently calculating for stock: ACSF (progress: 144 of 341)
# Currently calculating for stock: AETI (progress: 145 of 341)
# Currently calculating for stock: AMNB (progress: 146 of 341)
# Currently calculating for stock: ANAT (progress: 147 of 341)
# Currently calculating for stock: AOBC (progress: 148 of 341)
# Currently calculating for stock: APEI (progress: 149 of 341)
# Currently calculating for stock: ARII (progress: 150 of 341)
# Currently calculating for stock: AMRB (progress: 151 of 341)
# Currently calculating for stock: AMSWA (progress: 152 of 341)
# Currently calculating for stock: AMSC (progress: 153 of 341)
# Currently calculating for stock: AMWD (progress: 154 of 341)
# Currently calculating for stock: CRMT (progress: 155 of 341)
# Currently calculating for stock: ABCB (progress: 156 of 341)
# Currently calculating for stock: AMSF (progress: 157 of 341)
# Currently calculating for stock: ASRV (progress: 158 of 341)
# Currently calculating for stock: ASRVP (progress: 159 of 341)
# Currently calculating for stock: ATLO (progress: 160 of 341)
# Currently calculating for stock: AMGN (progress: 161 of 341)
# Currently calculating for stock: FOLD (progress: 162 of 341)
# Currently calculating for stock: AMKR (progress: 163 of 341)
# Currently calculating for stock: AMPH (progress: 164 of 341)
# Currently calculating for stock: IBUY (progress: 165 of 341)
# Currently calculating for stock: ASYS (progress: 166 of 341)
# Currently calculating for stock: AFSI (progress: 167 of 341)
# Currently calculating for stock: AMRS (progress: 168 of 341)
# Currently calculating for stock: ADI (progress: 169 of 341)
# Currently calculating for stock: ALOG (progress: 170 of 341)
# Currently calculating for stock: ANAB (progress: 171 of 341)
# Currently calculating for stock: AVXL (progress: 172 of 341)
# Currently calculating for stock: ANCB (progress: 173 of 341)
# Currently calculating for stock: ANDA (progress: 174 of 341)
# Currently calculating for stock: ANDAR (progress: 175 of 341)
# Currently calculating for stock: ANDAU (progress: 176 of 341)
# Currently calculating for stock: ANDAW (progress: 177 of 341)
# Currently calculating for stock: ANGI (progress: 178 of 341)
# Currently calculating for stock: ANGO (progress: 179 of 341)
# Currently calculating for stock: ANIP (progress: 180 of 341)
# Currently calculating for stock: ANIK (progress: 181 of 341)
# Currently calculating for stock: ANSS (progress: 182 of 341)
# Currently calculating for stock: ATRS (progress: 183 of 341)
# Currently calculating for stock: ANTH (progress: 184 of 341)
# Currently calculating for stock: ABAC (progress: 185 of 341)
# Currently calculating for stock: APOG (progress: 186 of 341)
# Currently calculating for stock: APEN (progress: 187 of 341)
# Currently calculating for stock: AINV (progress: 188 of 341)
# Currently calculating for stock: APPF (progress: 189 of 341)
# Currently calculating for stock: APPN (progress: 190 of 341)
# Currently calculating for stock: AAPL (progress: 191 of 341)
# Currently calculating for stock: ARCI (progress: 192 of 341)
# Currently calculating for stock: APDN (progress: 193 of 341)
# Currently calculating for stock: APDNW (progress: 194 of 341)
# Currently calculating for stock: AGTC (progress: 195 of 341)
# Currently calculating for stock: AMAT (progress: 196 of 341)
# Currently calculating for stock: AAOI (progress: 197 of 341)
# Currently calculating for stock: AREX (progress: 198 of 341)
# Currently calculating for stock: APTI (progress: 199 of 341)
# Currently calculating for stock: APRI (progress: 200 of 341)
# Currently calculating for stock: APVO (progress: 201 of 341)
# Currently calculating for stock: APTO (progress: 202 of 341)
# Currently calculating for stock: AQMS (progress: 203 of 341)
# Currently calculating for stock: AQB (progress: 204 of 341)
# Currently calculating for stock: AQXP (progress: 205 of 341)
# Currently calculating for stock: ARDM (progress: 206 of 341)
# Currently calculating for stock: ARLZ (progress: 207 of 341)
# Currently calculating for stock: PETX (progress: 208 of 341)
# Currently calculating for stock: ABUS (progress: 209 of 341)
# Currently calculating for stock: ARCW (progress: 210 of 341)
# Currently calculating for stock: ABIO (progress: 211 of 341)
# Currently calculating for stock: RKDA (progress: 212 of 341)
# Currently calculating for stock: ARCB (progress: 213 of 341)
# Currently calculating for stock: ACGL (progress: 214 of 341)
# Currently calculating for stock: ACGLP (progress: 215 of 341)
# Currently calculating for stock: APLP (progress: 216 of 341)
# Currently calculating for stock: ARDX (progress: 217 of 341)
# Currently calculating for stock: ARNA (progress: 218 of 341)
# Currently calculating for stock: ARCC (progress: 219 of 341)
# Currently calculating for stock: ARGX (progress: 220 of 341)
# Currently calculating for stock: AGII (progress: 221 of 341)
# Currently calculating for stock: AGIIL (progress: 222 of 341)
# Currently calculating for stock: ARGS (progress: 223 of 341)
# Currently calculating for stock: ARIS (progress: 224 of 341)
# Currently calculating for stock: ARKR (progress: 225 of 341)
# Currently calculating for stock: ARTX (progress: 226 of 341)
# Currently calculating for stock: ARQL (progress: 227 of 341)
# Currently calculating for stock: ARRY (progress: 228 of 341)
# Currently calculating for stock: ARRS (progress: 229 of 341)
# Currently calculating for stock: DWAT (progress: 230 of 341)
# Currently calculating for stock: AROW (progress: 231 of 341)
# Currently calculating for stock: ARWR (progress: 232 of 341)
# Currently calculating for stock: ARTNA (progress: 233 of 341)
# Currently calculating for stock: ARTW (progress: 234 of 341)
# Currently calculating for stock: ASBB (progress: 235 of 341)
# Currently calculating for stock: ASNA (progress: 236 of 341)
# Currently calculating for stock: ASND (progress: 237 of 341)
# Currently calculating for stock: ASCMA (progress: 238 of 341)
# Currently calculating for stock: APWC (progress: 239 of 341)
# Currently calculating for stock: ASML (progress: 240 of 341)
# Currently calculating for stock: AZPN (progress: 241 of 341)
# Currently calculating for stock: ASMB (progress: 242 of 341)
# Currently calculating for stock: ASFI (progress: 243 of 341)
# Currently calculating for stock: ASTE (progress: 244 of 341)
# Currently calculating for stock: ATRO (progress: 245 of 341)
# Currently calculating for stock: ALOT (progress: 246 of 341)
# Currently calculating for stock: ASTC (progress: 247 of 341)
# Currently calculating for stock: ASUR (progress: 248 of 341)
# Currently calculating for stock: ASV (progress: 249 of 341)
# Currently calculating for stock: ATAI (progress: 250 of 341)
# Currently calculating for stock: ATRA (progress: 251 of 341)
# Currently calculating for stock: ATHN (progress: 252 of 341)
# Currently calculating for stock: ATNX (progress: 253 of 341)
# Currently calculating for stock: ATHX (progress: 254 of 341)
# Currently calculating for stock: AAPC (progress: 255 of 341)
# Currently calculating for stock: AAME (progress: 256 of 341)
# Currently calculating for stock: ACBI (progress: 257 of 341)
# Currently calculating for stock: ACFC (progress: 258 of 341)
# Currently calculating for stock: ABY (progress: 259 of 341)
# Currently calculating for stock: ATLC (progress: 260 of 341)
# Currently calculating for stock: AAWW (progress: 261 of 341)
# Currently calculating for stock: AFH (progress: 262 of 341)
# Currently calculating for stock: AFHBL (progress: 263 of 341)
# Currently calculating for stock: TEAM (progress: 264 of 341)
# Currently calculating for stock: ATNI (progress: 265 of 341)
# Currently calculating for stock: ATOM (progress: 266 of 341)
# Currently calculating for stock: ATOS (progress: 267 of 341)
# Currently calculating for stock: ATRC (progress: 268 of 341)
# Currently calculating for stock: ATRI (progress: 269 of 341)
# Currently calculating for stock: ATTU (progress: 270 of 341)
# Currently calculating for stock: LIFE (progress: 271 of 341)
# Currently calculating for stock: AUBN (progress: 272 of 341)
# Currently calculating for stock: BOLD (progress: 273 of 341)
# Currently calculating for stock: AUDC (progress: 274 of 341)
# Currently calculating for stock: AUPH (progress: 275 of 341)
# Currently calculating for stock: EARS (progress: 276 of 341)
# Currently calculating for stock: ABTL (progress: 277 of 341)
# Currently calculating for stock: ADSK (progress: 278 of 341)
# Currently calculating for stock: ADP (progress: 279 of 341)
# Currently calculating for stock: AVDL (progress: 280 of 341)
# Currently calculating for stock: ATXI (progress: 281 of 341)
# Currently calculating for stock: AVEO (progress: 282 of 341)
# Currently calculating for stock: AVXS (progress: 283 of 341)
# Currently calculating for stock: AVNW (progress: 284 of 341)
# Currently calculating for stock: AVID (progress: 285 of 341)
# Currently calculating for stock: AVGR (progress: 286 of 341)
# Currently calculating for stock: AVIR (progress: 287 of 341)
# Currently calculating for stock: CAR (progress: 288 of 341)
# Currently calculating for stock: AHPA (progress: 289 of 341)
# Currently calculating for stock: AHPAU (progress: 290 of 341)
# Currently calculating for stock: AHPAW (progress: 291 of 341)
# Currently calculating for stock: AWRE (progress: 292 of 341)
# Currently calculating for stock: AXAR (progress: 293 of 341)
# Currently calculating for stock: AXARU (progress: 294 of 341)
# Currently calculating for stock: AXARW (progress: 295 of 341)
# Currently calculating for stock: ACLS (progress: 296 of 341)
# Currently calculating for stock: AXGN (progress: 297 of 341)
# Currently calculating for stock: AAXN (progress: 298 of 341)
# Currently calculating for stock: AXSM (progress: 299 of 341)
# Currently calculating for stock: AXTI (progress: 300 of 341)
# Currently calculating for stock: AZRX (progress: 301 of 341)
# Currently calculating for stock: BCOM (progress: 302 of 341)
# Currently calculating for stock: RILY (progress: 303 of 341)
# Currently calculating for stock: RILYL (progress: 304 of 341)
# Currently calculating for stock: RILYZ (progress: 305 of 341)
# Currently calculating for stock: BOSC (progress: 306 of 341)
# Currently calculating for stock: BIDU (progress: 307 of 341)
# Currently calculating for stock: BCPC (progress: 308 of 341)
# Currently calculating for stock: BWINA (progress: 309 of 341)
# Currently calculating for stock: BWINB (progress: 310 of 341)
# Currently calculating for stock: BLDP (progress: 311 of 341)
# Currently calculating for stock: BANF (progress: 312 of 341)
# Currently calculating for stock: BANFP (progress: 313 of 341)
# Currently calculating for stock: BCTF (progress: 314 of 341)
# Currently calculating for stock: BKMU (progress: 315 of 341)
# Currently calculating for stock: BOCH (progress: 316 of 341)
# Currently calculating for stock: BMRC (progress: 317 of 341)
# Currently calculating for stock: BMLP (progress: 318 of 341)
# Currently calculating for stock: BKSC (progress: 319 of 341)
# Currently calculating for stock: BOTJ (progress: 320 of 341)
# Currently calculating for stock: OZRK (progress: 321 of 341)
# Currently calculating for stock: BFIN (progress: 322 of 341)
# Currently calculating for stock: BWFG (progress: 323 of 341)
# Currently calculating for stock: BANR (progress: 324 of 341)
# Currently calculating for stock: BZUN (progress: 325 of 341)
# Currently calculating for stock: TAPR (progress: 326 of 341)
# Currently calculating for stock: BHAC (progress: 327 of 341)
# Currently calculating for stock: BHACR (progress: 328 of 341)
# Currently calculating for stock: BHACU (progress: 329 of 341)
# Currently calculating for stock: BHACW (progress: 330 of 341)
# Currently calculating for stock: BBSI (progress: 331 of 341)
# Currently calculating for stock: BSET (progress: 332 of 341)
# Currently calculating for stock: BYBK (progress: 333 of 341)
# Currently calculating for stock: BV (progress: 334 of 341)
# Currently calculating for stock: BCBP (progress: 335 of 341)
# Currently calculating for stock: BECN (progress: 336 of 341)
# Currently calculating for stock: BSF (progress: 337 of 341)
# Currently calculating for stock: BBGI (progress: 338 of 341)
# Currently calculating for stock: BEBE (progress: 339 of 341)
# Currently calculating for stock: BBBY (progress: 340 of 341)
# Currently calculating for stock: BGNE (progress: 341 of 341)
# Currently calculating for stock: BELFA (progress: 342 of 341)
# Currently calculating for stock: BELFB (progress: 343 of 341)
# Currently calculating for stock: BLPH (progress: 344 of 341)
# Currently calculating for stock: BLCM (progress: 345 of 341)
# Currently calculating for stock: BNCL (progress: 346 of 341)
# Currently calculating for stock: BNFT (progress: 347 of 341)
# Currently calculating for stock: BNTC (progress: 348 of 341)
# Currently calculating for stock: BNTCW (progress: 349 of 341)
# Currently calculating for stock: BYSI (progress: 350 of 341)
# Currently calculating for stock: BGCP (progress: 351 of 341)
# Currently calculating for stock: BGFV (progress: 352 of 341)
# Currently calculating for stock: BASI (progress: 353 of 341)
# Currently calculating for stock: ORPN (progress: 354 of 341)
# Currently calculating for stock: BIOC (progress: 355 of 341)
# Currently calculating for stock: BCRX (progress: 356 of 341)
# Currently calculating for stock: BDSI (progress: 357 of 341)
# Currently calculating for stock: BIIB (progress: 358 of 341)
# Currently calculating for stock: BIOL (progress: 359 of 341)
# Currently calculating for stock: BLFS (progress: 360 of 341)
# Currently calculating for stock: BLRX (progress: 361 of 341)
# Currently calculating for stock: BMRN (progress: 362 of 341)
# Currently calculating for stock: BMRA (progress: 363 of 341)
# Currently calculating for stock: BVXV (progress: 364 of 341)
# Currently calculating for stock: BVXVW (progress: 365 of 341)
# Currently calculating for stock: BPTH (progress: 366 of 341)
# Currently calculating for stock: BIOP (progress: 367 of 341)
# Currently calculating for stock: BIOS (progress: 368 of 341)
# Currently calculating for stock: BBC (progress: 369 of 341)
# Currently calculating for stock: BBP (progress: 370 of 341)
# Currently calculating for stock: BSTC (progress: 371 of 341)
# Currently calculating for stock: BSTG (progress: 372 of 341)
# Currently calculating for stock: BSPM (progress: 373 of 341)
# Currently calculating for stock: TECH (progress: 374 of 341)
# Currently calculating for stock: BEAT (progress: 375 of 341)
# Currently calculating for stock: BIVV (progress: 376 of 341)
# Currently calculating for stock: BCACU (progress: 377 of 341)
# Currently calculating for stock: BJRI (progress: 378 of 341)
# Currently calculating for stock: BBOX (progress: 379 of 341)
# Currently calculating for stock: BDE (progress: 380 of 341)
# Currently calculating for stock: BLKB (progress: 381 of 341)
# Currently calculating for stock: BBRY (progress: 382 of 341)
# Currently calculating for stock: HAWK (progress: 383 of 341)
# Currently calculating for stock: BL (progress: 384 of 341)
# Currently calculating for stock: BKCC (progress: 385 of 341)
# Currently calculating for stock: ADRA (progress: 386 of 341)
# Currently calculating for stock: ADRD (progress: 387 of 341)
# Currently calculating for stock: ADRE (progress: 388 of 341)
# Currently calculating for stock: ADRU (progress: 389 of 341)
# Currently calculating for stock: BLMN (progress: 390 of 341)
# Currently calculating for stock: BCOR (progress: 391 of 341)
# Currently calculating for stock: BLBD (progress: 392 of 341)
# Currently calculating for stock: BUFF (progress: 393 of 341)

# %%
net_earnings = [];

for key in results_from_script:
    net_earnings.append(results_from_script[key][5] / results_from_script[key][4]);

# %%
## Mean of net earnings
print np.mean(net_earnings)
# Out:
# 1.06999973686

# %%
import matplotlib;
import matplotlib.pyplot as plt
# %matplotlib
# Out:
# Using matplotlib backend: MacOSX

# %%
net_earnings.index(3.446647479654608)

# %%
final_results.keys()[140]

# %%
len(net_earnings)
# Out:
# 75

# %%
plt.hist(net_earnings, normed=True, bins=30)
plt.ylabel('Percentage Returns');

# %% [markdown]
# #  Data from:
# http://finance.google.com/finance/getprices?i=600&p=30d&f=d,o,h,l,c,v&df=cpct&q=AMD
